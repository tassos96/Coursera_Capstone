# %% [markdown]
# <a href="https://colab.research.google.com/github/tassos96/Coursera_Capstone/blob/main/CapstoneProjectWeek3_Part3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Question 1

# %% [markdown]
# ##Import data

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

#After retreiving the URL and creating a Beautiful soup object*
wikipedia = requests.get('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M')
soup = BeautifulSoup(wikipedia.content, 'lxml')

#Create a list
table_contents = []

#Find table and table data
table = soup.find_all('table')[0]
for row in table.findAll('td'):
    cell = {}
    if row.span.text=='Not assigned':
        pass
    else:
        cell['Postal Code'] = row.p.text[:3]
        cell['Borough'] = (row.span.text).split('(')[0]
        cell['Neighbourhood'] = (((((row.span.text).split('(')[1]).strip(')')).replace(' /',',')).replace(')',' ')).strip(' ')
        table_contents.append(cell)

#Load table contents to a dataframe
df=pd.DataFrame(table_contents)
df['Borough']=df['Borough'].replace({'Downtown TorontoStn A PO Boxes25 The Esplanade':'Downtown Toronto Stn A',
                                             'East TorontoBusiness reply mail Processing Centre969 Eastern':'East Toronto Business',
                                             'EtobicokeNorthwest':'Etobicoke Northwest','East YorkEast Toronto':'East York/East Toronto',
                                             'MississaugaCanada Post Gateway Processing Centre':'Mississauga'})

#Print dataframe
df
# Out:
#     Postal Code  ...                                      Neighbourhood
# 0           M3A  ...                                          Parkwoods
# 1           M4A  ...                                   Victoria Village
# 2           M5A  ...                          Regent Park, Harbourfront
# 3           M6A  ...                   Lawrence Manor, Lawrence Heights
# 4           M7A  ...                      Ontario Provincial Government
# ..          ...  ...                                                ...
# 98          M8X  ...      The Kingsway, Montgomery Road, Old Mill North
# 99          M4Y  ...                               Church and Wellesley
# 100         M7Y  ...                                     Enclave of M4L
# 101         M8Y  ...  Old Mill South, King's Mill Park, Sunnylea, Hu...
# 102         M8Z  ...  Mimico NW, The Queensway West, South of Bloor,...
#
# [103 rows x 3 columns]

# %%
#Print dataframe shape
print(df.shape)
# Out:
# (103, 3)

# %% [markdown]
# #Question 2

# %% [markdown]
# ##Import and install geocoder

# %%
# !pip install geocoder
import geocoder

# %% [markdown]
# ##The below suggested approach does not run.

# %%
# # initialize your variable to None
# lat_lng_coords = None

# postal_code = 'M3A'

# # loop until you get the coordinates
# while(lat_lng_coords is None):
#   g = geocoder.google('{}, Toronto, Ontario'.format(postal_code))
#   lat_lng_coords = g.latlng

# latitude = lat_lng_coords[0]
# longitude = lat_lng_coords[1]

# %% [markdown]
# ##Alternative approach as suggested in the assignment

# %%
data = pd.read_csv("https://cocl.us/Geospatial_data")
data
# Out:
#     Postal Code   Latitude  Longitude
# 0           M1B  43.806686 -79.194353
# 1           M1C  43.784535 -79.160497
# 2           M1E  43.763573 -79.188711
# 3           M1G  43.770992 -79.216917
# 4           M1H  43.773136 -79.239476
# ..          ...        ...        ...
# 98          M9N  43.706876 -79.518188
# 99          M9P  43.696319 -79.532242
# 100         M9R  43.688905 -79.554724
# 101         M9V  43.739416 -79.588437
# 102         M9W  43.706748 -79.594054
#
# [103 rows x 3 columns]

# %%
final_data = df.join(data.set_index('Postal Code'), on = 'Postal Code', how='inner') 
final_data
# Out:
#     Postal Code                Borough  ...   Latitude  Longitude
# 0           M3A             North York  ...  43.753259 -79.329656
# 1           M4A             North York  ...  43.725882 -79.315572
# 2           M5A       Downtown Toronto  ...  43.654260 -79.360636
# 3           M6A             North York  ...  43.718518 -79.464763
# 4           M7A           Queen's Park  ...  43.662301 -79.389494
# ..          ...                    ...  ...        ...        ...
# 98          M8X              Etobicoke  ...  43.653654 -79.506944
# 99          M4Y       Downtown Toronto  ...  43.665860 -79.383160
# 100         M7Y  East Toronto Business  ...  43.662744 -79.321558
# 101         M8Y              Etobicoke  ...  43.636258 -79.498509
# 102         M8Z              Etobicoke  ...  43.628841 -79.520999
#
# [103 rows x 5 columns]

# %%
#Print final data shape
print(final_data.shape)
# Out:
# (103, 5)

# %% [markdown]
# #Question 3

# %% [markdown]
# ##Based on lab from NYC neighbourhood we have to follow the same method

# %%
#Install and import Nominatim
# !pip install geopy
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

# %%
#Find Toronto's coordinates
address = 'Toronto, Ontario'

geolocator = Nominatim(user_agent="toronto_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The coordinates of Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The coordinates of Toronto are 43.6534817, -79.3839347.

# %%
#Import folium
import folium

# %%
#Visualise on map
torontoMap = folium.Map(location=[latitude, longitude], zoom_start=11)


# adding markers to map
for latitude, longitude, borough, neighbourhood in zip(final_data['Latitude'], final_data['Longitude'], final_data['Borough'], final_data['Neighbourhood']):
    label = '{}, {}'.format(neighbourhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [latitude, longitude],
        radius=5,
        popup=label,
        color='red',
        fill=True
        ).add_to(torontoMap)  
    
torontoMap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.co
# ...

# %%
#Initialize Foursquare API credentials
CLIENT_ID = '5DJBSQOGV4XVB34W1YJEUWREADLVPS0JP5IJKYZGDZYQHZPV'
CLIENT_SECRET = 'NBY5JXAM224OZEZSPPMOXKT4TYJH5NSN5LSMVNR3FSFVFRCG' 
VERSION = '20180604'

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: 5DJBSQOGV4XVB34W1YJEUWREADLVPS0JP5IJKYZGDZYQHZPV
# CLIENT_SECRET:NBY5JXAM224OZEZSPPMOXKT4TYJH5NSN5LSMVNR3FSFVFRCG

# %%
#Define a method to collect all nearby venues
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        #print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius
            )
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighbourhood', 
                  'Neighbourhood Latitude', 
                  'Neighbourhood Longitude', 
                  'Venue', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
#Gather oronto venues
torontoVenues = getNearbyVenues(final_data['Neighbourhood'], final_data['Latitude'], final_data['Longitude'])

# %%
#Display first venues
torontoVenues.head()
# Out:
#       Neighbourhood  ...              Venue Category
# 0         Parkwoods  ...        Fast Food Restaurant
# 1         Parkwoods  ...                        Park
# 2         Parkwoods  ...           Food & Drink Shop
# 3         Parkwoods  ...  Construction & Landscaping
# 4  Victoria Village  ...                Hockey Arena
#
# [5 rows x 5 columns]

# %%
#Group venues by neighbourhood and find the unique
torontoVenues.groupby('Neighbourhood').count()
# Out:
#                                                  Neighbourhood Latitude  ...  Venue Category
# Neighbourhood                                                            ...
# Agincourt                                                             4  ...               4
# Alderwood, Long Branch                                                8  ...               8
# Bathurst Manor, Wilson Heights, Downsview North                      18  ...              18
# Bayview Village                                                       4  ...               4
# Bedford Park, Lawrence Manor East                                    22  ...              22
# ...                                                                 ...  ...             ...
# Willowdale West                                                       5  ...               5
# Willowdale, Newtonbrook                                               2  ...               2
# ...

# %%
#Find unique venues per neighbourhood
print('There are {} uniques categories.'.format(len(torontoVenues['Venue Category'].unique())))
# Out:
# There are 224 uniques categories.

# %%
#Create one hot encoding
toronto_onehot = pd.get_dummies(torontoVenues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
toronto_onehot['Neighbourhood'] = torontoVenues['Neighbourhood'] 

# moving neighborhood column to the first column
fixed_columns = [toronto_onehot.columns[-1]] + list(toronto_onehot.columns[:-1])
toronto_onehot = toronto_onehot[fixed_columns]

toronto_onehot.head()
# Out:
#       Neighbourhood  Adult Boutique  ...  Women's Store  Yoga Studio
# 0         Parkwoods               0  ...              0            0
# 1         Parkwoods               0  ...              0            0
# 2         Parkwoods               0  ...              0            0
# 3         Parkwoods               0  ...              0            0
# 4  Victoria Village               0  ...              0            0
#
# [5 rows x 225 columns]

# %%
#Group by neighbourhood
toronto_grouped = toronto_onehot.groupby('Neighbourhood').mean().reset_index()
toronto_grouped.head()
# Out:
#                                      Neighbourhood  ...  Yoga Studio
# 0                                        Agincourt  ...          0.0
# 1                           Alderwood, Long Branch  ...          0.0
# 2  Bathurst Manor, Wilson Heights, Downsview North  ...          0.0
# 3                                  Bayview Village  ...          0.0
# 4                Bedford Park, Lawrence Manor East  ...          0.0
#
# [5 rows x 225 columns]

# %%
#Define a method to get most common venues in descending order
def getMostCommonVenues(row, num_top_venues):
  row_categories = row.iloc[1:]
  row_categories_sorted = row_categories.sort_values(ascending=False)
    
  return row_categories_sorted.index.values[0:num_top_venues]

# %%
#Import numpy
import numpy as np

# %%
#Take the top 10 venues. We will use them for clustering
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighbourhood']
for i in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(i+1, indicators[i]))
    except:
        columns.append('{}th Most Common Venue'.format(i+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighbourhood'] = toronto_grouped['Neighbourhood']

for i in np.arange(toronto_grouped.shape[0]):
  neighborhoods_venues_sorted.iloc[i, 1:] = getMostCommonVenues(toronto_grouped.iloc[i, :], num_top_venues)

neighborhoods_venues_sorted.head()
# Out:
#                                      Neighbourhood  ...       10th Most Common Venue
# 0                                        Agincourt  ...  Eastern European Restaurant
# 1                           Alderwood, Long Branch  ...           Dim Sum Restaurant
# 2  Bathurst Manor, Wilson Heights, Downsview North  ...             Sushi Restaurant
# 3                                  Bayview Village  ...  Eastern European Restaurant
# 4                Bedford Park, Lawrence Manor East  ...                         Café
#
# [5 rows x 11 columns]

# %% [markdown]
# ##Clustering

# %%
#Import k-means cluster
from sklearn.cluster import KMeans

# %%
# set number of clusters
clustersNum = 5

toronto_grouped_clustering = toronto_grouped.drop('Neighbourhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=clustersNum, random_state=0).fit(toronto_grouped_clustering)
kmeans
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=5, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=0, tol=0.0001, verbose=0)

# %%
kmeans.labels_
# Out:
# array([4, 0, 4, 4, 4, 4, 4, 4, 4, 2, 4, 4, 4, 4, 4, 0, 4, 4, 4, 4, 4, 4,
#        4, 4, 4, 2, 4, 4, 4, 4, 4, 4, 0, 4, 4, 4, 4, 4, 4, 4, 4, 4, 1, 4,
#        3, 4, 4, 4, 4, 0, 4, 4, 4, 4, 1, 2, 4, 4, 4, 4, 4, 4, 3, 4, 4, 0,
#        1, 4, 4, 2, 1, 4, 4, 0, 0, 0, 4, 4, 4, 4, 4, 4, 0, 2, 4, 2, 4, 4,
#        4, 0, 4, 0, 4, 4, 0, 2, 4, 4, 2], dtype=int32)

# %%
#Add clustering label column to most common venues
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)
neighborhoods_venues_sorted
# Out:
#     Cluster Labels  ...       10th Most Common Venue
# 0                4  ...  Eastern European Restaurant
# 1                0  ...           Dim Sum Restaurant
# 2                4  ...             Sushi Restaurant
# 3                4  ...  Eastern European Restaurant
# 4                4  ...                         Café
# ..             ...  ...                          ...
# 94               0  ...  Eastern European Restaurant
# 95               2  ...                   Donut Shop
# 96               4  ...                    Drugstore
# 97               4  ...            Electronics Store
# 98               2  ...                    Drugstore
#
# [99 rows x 12 columns]

# %%
#Combine final_data with neighborhoods_venues_sorted
toronto_merged = final_data
toronto_merged.reset_index()
toronto_merged = toronto_merged.join(neighborhoods_venues_sorted.set_index('Neighbourhood'), on='Neighbourhood')

toronto_merged.head()
# Out:
#   Postal Code  ...       10th Most Common Venue
# 0         M3A  ...  Eastern European Restaurant
# 1         M4A  ...                    Drugstore
# 2         M5A  ...            French Restaurant
# 3         M6A  ...            Electronics Store
# 4         M7A  ...                         Café
#
# [5 rows x 16 columns]

# %%
#drop nan
toronto_merged = toronto_merged.dropna(subset=['Cluster Labels'])

# %%
#import libraries for visualization
import matplotlib.cm as cm
import matplotlib.colors as colors

# %%
#Visualize clusters on map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(clustersNum)
ys = [i + x + (i*x)**2 for i in range(clustersNum)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(toronto_merged['Latitude'], toronto_merged['Longitude'], toronto_merged['Neighbourhood'], toronto_merged['Cluster Labels']):
    label = folium.Popup('Cluster ' + str(int(cluster) +1) + '\n' + str(poi) , parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[int(cluster-1)],
        fill=True,
        fill_color=rainbow[int(cluster-1)]
        ).add_to(map_clusters)
        
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.co
# ...

# %% [markdown]
# ##Examine Clusters

# %%
#Cluster 1
toronto_merged.loc[toronto_merged['Cluster Labels'] == 0, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#          Borough  ...       10th Most Common Venue
# 1     North York  ...                    Drugstore
# 8      East York  ...  Eastern European Restaurant
# 17     Etobicoke  ...  Eastern European Restaurant
# 19  East Toronto  ...                    Drugstore
# 32   Scarborough  ...                      Dog Run
# 63          York  ...  Eastern European Restaurant
# 70     Etobicoke  ...                   Donut Shop
# 72    North York  ...  Eastern European Restaurant
# 77     Etobicoke  ...  Eastern European Restaurant
# 82   Scarborough  ...                     Pharmacy
# 89     Etobicoke  ...  Eastern European Restaurant
# 93     Etobicoke  ...           Dim Sum Restaurant
#
# [12 rows x 12 columns]

# %%
#Cluster 2
toronto_merged.loc[toronto_merged['Cluster Labels'] == 1, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#             Borough  ...       10th Most Common Venue
# 0        North York  ...  Eastern European Restaurant
# 6       Scarborough  ...                   Donut Shop
# 27       North York  ...  Eastern European Restaurant
# 62  Central Toronto  ...                      Dog Run
#
# [4 rows x 12 columns]

# %%
#Cluster 3
toronto_merged.loc[toronto_merged['Cluster Labels'] == 2, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#                    Borough  ...  10th Most Common Venue
# 21                    York  ...              Donut Shop
# 35  East York/East Toronto  ...               Drugstore
# 40              North York  ...               Drugstore
# 52              North York  ...              Donut Shop
# 66              North York  ...               Drugstore
# 85             Scarborough  ...               Drugstore
# 91        Downtown Toronto  ...              Donut Shop
# 98               Etobicoke  ...              Donut Shop
#
# [8 rows x 12 columns]

# %%
#Cluster 4
toronto_merged.loc[toronto_merged['Cluster Labels'] == 3, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#         Borough  ...  10th Most Common Venue
# 57   North York  ...               Drugstore
# 101   Etobicoke  ...               Drugstore
#
# [2 rows x 12 columns]

# %%
#Cluster 5
toronto_merged.loc[toronto_merged['Cluster Labels'] == 4, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#                    Borough  ...       10th Most Common Venue
# 2         Downtown Toronto  ...            French Restaurant
# 3               North York  ...            Electronics Store
# 4             Queen's Park  ...                         Café
# 7               North York  ...  Eastern European Restaurant
# 9         Downtown Toronto  ...           Falafel Restaurant
# ..                     ...  ...                          ...
# 96        Downtown Toronto  ...         Taiwanese Restaurant
# 97        Downtown Toronto  ...          Japanese Restaurant
# 99        Downtown Toronto  ...                   Restaurant
# 100  East Toronto Business  ...             Recording Studio
# 102              Etobicoke  ...            Convenience Store
#
# [73 rows x 12 columns]
